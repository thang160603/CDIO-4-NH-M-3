-- %% [markdown]
-- # [TEST]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [TEST]    Script Date: 19/6/2024 10:43:20 AM ******/
CREATE DATABASE [TEST]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'TEST', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\TEST.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'TEST_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\TEST_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [TEST] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [TEST].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [TEST] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [TEST] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [TEST] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [TEST] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [TEST] SET ARITHABORT OFF 
GO
ALTER DATABASE [TEST] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [TEST] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [TEST] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [TEST] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [TEST] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [TEST] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [TEST] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [TEST] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [TEST] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [TEST] SET  DISABLE_BROKER 
GO
ALTER DATABASE [TEST] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [TEST] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [TEST] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [TEST] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [TEST] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [TEST] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [TEST] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [TEST] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [TEST] SET  MULTI_USER 
GO
ALTER DATABASE [TEST] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [TEST] SET DB_CHAINING OFF 
GO
ALTER DATABASE [TEST] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [TEST] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [TEST] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [TEST] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [TEST] SET QUERY_STORE = ON
GO
ALTER DATABASE [TEST] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[chi_tiet_hoa_don]

-- %%
USE [TEST]
GO

-- %%
/****** Object:  Table [dbo].[chi_tiet_hoa_don]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[chi_tiet_hoa_don](
	[ma_chi_tiet_hoa_don] [int] IDENTITY(1,1) NOT NULL,
	[ma_don_hang] [int] NULL,
	[ma_san_pham] [int] NULL,
	[so_luong] [int] NOT NULL,
	[don_gia] [decimal](10, 2) NOT NULL,
	[thanh_tien] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_chi_tiet_hoa_don] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[chi_tiet_hoa_don_nhap]

-- %%
/****** Object:  Table [dbo].[chi_tiet_hoa_don_nhap]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[chi_tiet_hoa_don_nhap](
	[ma_chi_tiet_nhap] [nchar](10) NOT NULL,
	[ma_nhap_kho] [int] NOT NULL,
	[ma_san_Pham] [int] NOT NULL,
	[so_luong] [int] NULL,
	[thanh_tien] [decimal](18, 0) NULL,
	[don_gia] [decimal](18, 0) NULL,
 CONSTRAINT [PK_chi_tiet_hoa_don_nhap] PRIMARY KEY CLUSTERED 
(
	[ma_chi_tiet_nhap] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[danh_gia]

-- %%
/****** Object:  Table [dbo].[danh_gia]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[danh_gia](
	[ma_danh_gia] [int] IDENTITY(1,1) NOT NULL,
	[ma_san_pham] [int] NULL,
	[ma_nguoi_dung] [int] NULL,
	[noi_dung] [text] NOT NULL,
	[diem] [int] NOT NULL,
	[ngay_danh_gia] [date] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_danh_gia] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[danh_muc]

-- %%
/****** Object:  Table [dbo].[danh_muc]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[danh_muc](
	[ma_danh_muc] [int] IDENTITY(1,1) NOT NULL,
	[ten_danh_muc] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_danh_muc] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[don_hang]

-- %%
/****** Object:  Table [dbo].[don_hang]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[don_hang](
	[ma_don_hang] [int] IDENTITY(1,1) NOT NULL,
	[ma_nguoi_dung] [int] NULL,
	[ngay_dat] [date] NOT NULL,
	[tong_tien] [decimal](10, 2) NOT NULL,
	[trang_thai] [varchar](50) NOT NULL,
	[ma_phuong_thuc_thanh_toan] [int] NULL,
	[ma_van_chuyen] [int] NULL,
	[Phuong_thuc_thanh_toan] [nvarchar](50) NULL,
	[ma_danh_gia] [int] NOT NULL,
	[ma_vocucher] [int] NOT NULL,
 CONSTRAINT [PK__don_hang__0246C5EA9ABA5145] PRIMARY KEY CLUSTERED 
(
	[ma_don_hang] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[hoa_don_nhap_xuat_kho]

-- %%
/****** Object:  Table [dbo].[hoa_don_nhap_xuat_kho]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[hoa_don_nhap_xuat_kho](
	[ma_hoa_don_nhap_xuat] [int] NOT NULL,
	[so_luong] [int] NULL,
	[thanh_tien] [decimal](18, 0) NULL,
 CONSTRAINT [PK_hoa_don_nhap_xuat_kho] PRIMARY KEY CLUSTERED 
(
	[ma_hoa_don_nhap_xuat] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[nguoi_dung]

-- %%
/****** Object:  Table [dbo].[nguoi_dung]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[nguoi_dung](
	[ma_nguoi_dung] [int] IDENTITY(1,1) NOT NULL,
	[ten_dang_nhap] [varchar](50) NOT NULL,
	[mat_khau] [varchar](255) NOT NULL,
	[email] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_nguoi_dung] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[ten_dang_nhap] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[nha_cung_cap]

-- %%
/****** Object:  Table [dbo].[nha_cung_cap]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[nha_cung_cap](
	[ma_nha_cung_cap] [int] IDENTITY(1,1) NOT NULL,
	[ten_nha_cung_cap] [varchar](100) NOT NULL,
	[thong_tin_lien_he] [varchar](255) NULL,
	[ten_dang_nhap] [nvarchar](50) NOT NULL,
	[Mat_khau] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK__nha_cung__9B34E6DBFCDBD06E] PRIMARY KEY CLUSTERED 
(
	[ma_nha_cung_cap] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[nhap_kho]

-- %%
/****** Object:  Table [dbo].[nhap_kho]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[nhap_kho](
	[ma_nhap_kho] [int] IDENTITY(1,1) NOT NULL,
	[ma_san_pham] [int] NULL,
	[ma_nha_cung_cap] [int] NULL,
	[so_luong] [int] NOT NULL,
	[ngay_nhap] [date] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_nhap_kho] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[phuong_thuc_thanh_toan]

-- %%
/****** Object:  Table [dbo].[phuong_thuc_thanh_toan]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[phuong_thuc_thanh_toan](
	[ma_phuong_thuc_thanh_toan] [int] IDENTITY(1,1) NOT NULL,
	[ten_phuong_thuc] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_phuong_thuc_thanh_toan] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[san_pham]

-- %%
/****** Object:  Table [dbo].[san_pham]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[san_pham](
	[ma_san_pham] [int] IDENTITY(1,1) NOT NULL,
	[ten_san_pham] [varchar](100) NOT NULL,
	[mo_ta] [text] NULL,
	[gia] [decimal](10, 2) NOT NULL,
	[ma_danh_muc] [int] NULL,
	[so_luong_ton] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_san_pham] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[san_pham_nha_cung_cap]

-- %%
/****** Object:  Table [dbo].[san_pham_nha_cung_cap]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[san_pham_nha_cung_cap](
	[ma_san_pham_nha_cung_cap] [int] IDENTITY(1,1) NOT NULL,
	[ma_san_pham] [int] NULL,
	[ma_nha_cung_cap] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_san_pham_nha_cung_cap] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vai_tro]

-- %%
/****** Object:  Table [dbo].[vai_tro]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[vai_tro](
	[ma_vai_tro] [int] IDENTITY(1,1) NOT NULL,
	[ten_vai_tro] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_vai_tro] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vai_tro_nguoi_dung]

-- %%
/****** Object:  Table [dbo].[vai_tro_nguoi_dung]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[vai_tro_nguoi_dung](
	[ma_vai_tro_nguoi_dung] [int] IDENTITY(1,1) NOT NULL,
	[ma_nguoi_dung] [int] NULL,
	[ma_vai_tro] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_vai_tro_nguoi_dung] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[van_chuyen]

-- %%
/****** Object:  Table [dbo].[van_chuyen]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[van_chuyen](
	[ma_van_chuyen] [int] IDENTITY(1,1) NOT NULL,
	[ten_van_chuyen] [varchar](100) NOT NULL,
	[phi_van_chuyen] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_van_chuyen] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[voucher]

-- %%
/****** Object:  Table [dbo].[voucher]    Script Date: 19/6/2024 10:43:20 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[voucher](
	[ma_voucher] [int] IDENTITY(1,1) NOT NULL,
	[ma_nguoi_dung] [int] NULL,
	[ten_voucher] [varchar](100) NOT NULL,
	[gia_tri] [decimal](10, 2) NOT NULL,
	[ngay_bat_dau] [date] NOT NULL,
	[ngay_het_han] [date] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ma_voucher] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__san_pham__so_luo__48CFD27E]

-- %%
ALTER TABLE [dbo].[san_pham] ADD  DEFAULT ((0)) FOR [so_luong_ton]
GO

-- %% [markdown]
-- # [FK__chi_tiet___ma_do__5535A963]

-- %%
ALTER TABLE [dbo].[chi_tiet_hoa_don]  WITH CHECK ADD  CONSTRAINT [FK__chi_tiet___ma_do__5535A963] FOREIGN KEY([ma_don_hang])
REFERENCES [dbo].[don_hang] ([ma_don_hang])
GO
ALTER TABLE [dbo].[chi_tiet_hoa_don] CHECK CONSTRAINT [FK__chi_tiet___ma_do__5535A963]
GO

-- %% [markdown]
-- # [FK__chi_tiet___ma_sa__5629CD9C]

-- %%
ALTER TABLE [dbo].[chi_tiet_hoa_don]  WITH CHECK ADD FOREIGN KEY([ma_san_pham])
REFERENCES [dbo].[san_pham] ([ma_san_pham])
GO

-- %% [markdown]
-- # [FK_chi_tiet_hoa_don_nhap_nhap_kho]

-- %%
ALTER TABLE [dbo].[chi_tiet_hoa_don_nhap]  WITH CHECK ADD  CONSTRAINT [FK_chi_tiet_hoa_don_nhap_nhap_kho] FOREIGN KEY([ma_nhap_kho])
REFERENCES [dbo].[nhap_kho] ([ma_nhap_kho])
GO
ALTER TABLE [dbo].[chi_tiet_hoa_don_nhap] CHECK CONSTRAINT [FK_chi_tiet_hoa_don_nhap_nhap_kho]
GO

-- %% [markdown]
-- # [FK_chi_tiet_hoa_don_nhap_san_pham]

-- %%
ALTER TABLE [dbo].[chi_tiet_hoa_don_nhap]  WITH CHECK ADD  CONSTRAINT [FK_chi_tiet_hoa_don_nhap_san_pham] FOREIGN KEY([ma_san_Pham])
REFERENCES [dbo].[san_pham] ([ma_san_pham])
GO
ALTER TABLE [dbo].[chi_tiet_hoa_don_nhap] CHECK CONSTRAINT [FK_chi_tiet_hoa_don_nhap_san_pham]
GO

-- %% [markdown]
-- # [FK__don_hang__ma_ngu__5070F446]

-- %%
ALTER TABLE [dbo].[don_hang]  WITH CHECK ADD  CONSTRAINT [FK__don_hang__ma_ngu__5070F446] FOREIGN KEY([ma_nguoi_dung])
REFERENCES [dbo].[nguoi_dung] ([ma_nguoi_dung])
GO
ALTER TABLE [dbo].[don_hang] CHECK CONSTRAINT [FK__don_hang__ma_ngu__5070F446]
GO

-- %% [markdown]
-- # [FK__don_hang__ma_phu__5165187F]

-- %%
ALTER TABLE [dbo].[don_hang]  WITH CHECK ADD  CONSTRAINT [FK__don_hang__ma_phu__5165187F] FOREIGN KEY([ma_phuong_thuc_thanh_toan])
REFERENCES [dbo].[phuong_thuc_thanh_toan] ([ma_phuong_thuc_thanh_toan])
GO
ALTER TABLE [dbo].[don_hang] CHECK CONSTRAINT [FK__don_hang__ma_phu__5165187F]
GO

-- %% [markdown]
-- # [FK__don_hang__ma_van__52593CB8]

-- %%
ALTER TABLE [dbo].[don_hang]  WITH CHECK ADD  CONSTRAINT [FK__don_hang__ma_van__52593CB8] FOREIGN KEY([ma_van_chuyen])
REFERENCES [dbo].[van_chuyen] ([ma_van_chuyen])
GO
ALTER TABLE [dbo].[don_hang] CHECK CONSTRAINT [FK__don_hang__ma_van__52593CB8]
GO

-- %% [markdown]
-- # [FK_don_hang_danh_gia]

-- %%
ALTER TABLE [dbo].[don_hang]  WITH CHECK ADD  CONSTRAINT [FK_don_hang_danh_gia] FOREIGN KEY([ma_danh_gia])
REFERENCES [dbo].[danh_gia] ([ma_danh_gia])
GO
ALTER TABLE [dbo].[don_hang] CHECK CONSTRAINT [FK_don_hang_danh_gia]
GO

-- %% [markdown]
-- # [FK_don_hang_voucher]

-- %%
ALTER TABLE [dbo].[don_hang]  WITH CHECK ADD  CONSTRAINT [FK_don_hang_voucher] FOREIGN KEY([ma_vocucher])
REFERENCES [dbo].[voucher] ([ma_voucher])
GO
ALTER TABLE [dbo].[don_hang] CHECK CONSTRAINT [FK_don_hang_voucher]
GO

-- %% [markdown]
-- # [FK__nhap_kho__ma_nha__4D94879B]

-- %%
ALTER TABLE [dbo].[nhap_kho]  WITH CHECK ADD  CONSTRAINT [FK__nhap_kho__ma_nha__4D94879B] FOREIGN KEY([ma_nha_cung_cap])
REFERENCES [dbo].[nha_cung_cap] ([ma_nha_cung_cap])
GO
ALTER TABLE [dbo].[nhap_kho] CHECK CONSTRAINT [FK__nhap_kho__ma_nha__4D94879B]
GO

-- %% [markdown]
-- # [FK__nhap_kho__ma_san__4CA06362]

-- %%
ALTER TABLE [dbo].[nhap_kho]  WITH CHECK ADD FOREIGN KEY([ma_san_pham])
REFERENCES [dbo].[san_pham] ([ma_san_pham])
GO

-- %% [markdown]
-- # [FK__san_pham__ma_dan__49C3F6B7]

-- %%
ALTER TABLE [dbo].[san_pham]  WITH CHECK ADD FOREIGN KEY([ma_danh_muc])
REFERENCES [dbo].[danh_muc] ([ma_danh_muc])
GO

-- %% [markdown]
-- # [FK__san_pham___ma_nh__59FA5E80]

-- %%
ALTER TABLE [dbo].[san_pham_nha_cung_cap]  WITH CHECK ADD  CONSTRAINT [FK__san_pham___ma_nh__59FA5E80] FOREIGN KEY([ma_nha_cung_cap])
REFERENCES [dbo].[nha_cung_cap] ([ma_nha_cung_cap])
GO
ALTER TABLE [dbo].[san_pham_nha_cung_cap] CHECK CONSTRAINT [FK__san_pham___ma_nh__59FA5E80]
GO

-- %% [markdown]
-- # [FK__san_pham___ma_sa__59063A47]

-- %%
ALTER TABLE [dbo].[san_pham_nha_cung_cap]  WITH CHECK ADD FOREIGN KEY([ma_san_pham])
REFERENCES [dbo].[san_pham] ([ma_san_pham])
GO

-- %% [markdown]
-- # [FK__vai_tro_n__ma_ng__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[vai_tro_nguoi_dung]  WITH CHECK ADD FOREIGN KEY([ma_nguoi_dung])
REFERENCES [dbo].[nguoi_dung] ([ma_nguoi_dung])
GO

-- %% [markdown]
-- # [FK__vai_tro_n__ma_va__3E52440B]

-- %%
ALTER TABLE [dbo].[vai_tro_nguoi_dung]  WITH CHECK ADD FOREIGN KEY([ma_vai_tro])
REFERENCES [dbo].[vai_tro] ([ma_vai_tro])
GO

-- %% [markdown]
-- # [CK__danh_gia__diem__5FB337D6]

-- %%
ALTER TABLE [dbo].[danh_gia]  WITH CHECK ADD CHECK  (([diem]>=(1) AND [diem]<=(5)))
GO

-- %% [markdown]
-- # [TEST]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [TEST] SET  READ_WRITE 
GO
